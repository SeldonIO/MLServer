# %%
import requests
from time import perf_counter
from random import random
inference_request = {
"inputs": [
    {
        "name": "questions",
        "datatype": "BYTES",
        "parameters": {
            "content_type": "str"
        },
        "shape": [5],
        "data": ["To sorry world an at do spoil along. Incommode he depending do frankness remainder to. Edward day almost active him friend thirty piqued. People as period twenty my extent as. Set was better abroad ham plenty secure had horse", 
                  "Be at miss or each good play home they. It leave taste mr in it fancy. She son lose does fond bred gave lady get. Sir her company conduct expense bed any. Sister depend change off piqued one. Contented continued any happiness instantly objection yet her allowance. Use correct day new brought tedious. By come this been in. Kept easy or sons my it done.",
                  "Attention he extremity unwilling on otherwise. Conviction up partiality as delightful is discovered. Yet jennings resolved disposed exertion you off. Left did fond drew fat head poor. So if he into shot half many long. China fully him every fat was world grave.",
                  "Do in laughter securing smallest sensible no mr hastened. As perhaps proceed in in brandon of limited unknown greatly. Distrusts fulfilled happiness unwilling as explained of difficult. No landlord of peculiar ladyship attended if contempt ecstatic. Loud wish made on is am as hard. Court so avoid in plate hence. Of received mr breeding concerns peculiar securing landlord. Spot to many it four bred soon well to. Or am promotion in no departure abilities. Whatever landlord yourself at by pleasure of children be.",
                  str(random()*1000000)]
    }
]
}
start_time = perf_counter()
for i in range(50) :
  print(f" start request {i}")
  response = requests.post("http://localhost:8080/v2/models/sentence-transformer/infer", json=inference_request).json()
  print(f" end request {i}")
print(response)
print(f"time taken is {perf_counter() - start_time}")
# Out:
#  start request 0
#  end request 0
#  start request 1
#  end request 1
#  start request 2
#  end request 2
#  start request 3
#  end request 3
#  start request 4
#  end request 4
#  start request 5
#  end request 5
#  start request 6
#  end request 6
#  start request 7
#  end request 7
#  start request 8
#  end request 8
#  start request 9
#  end request 9
#  start request 10
#  end request 10
#  start request 11
#  end request 11
#  start request 12
#  end request 12
#  start request 13
#  end request 13
#  start request 14
#  end request 14
#  start request 15
#  end request 15
#  start request 16
#  end request 16
#  start request 17
#  end request 17
#  start request 18
#  end request 18
#  start request 19
#  end request 19
#  start request 20
#  end request 20
#  start request 21
#  end request 21
#  start request 22
#  end request 22
#  start request 23
#  end request 23
#  start request 24
#  end request 24
#  start request 25
#  end request 25
#  start request 26
#  end request 26
#  start request 27
#  end request 27
#  start request 28
#  end request 28
#  start request 29
#  end request 29
#  start request 30
#  end request 30
#  start request 31
#  end request 31
#  start request 32
#  end request 32
#  start request 33
#  end request 33
#  start request 34
#  end request 34
#  start request 35
#  end request 35
#  start request 36
#  end request 36
#  start request 37
#  end request 37
#  start request 38
#  end request 38
#  start request 39
#  end request 39
#  start request 40
#  end request 40
#  start request 41
#  end request 41
#  start request 42
#  end request 42
#  start request 43
#  end request 43
#  start request 44
#  end request 44
#  start request 45
#  end request 45
#  start request 46
#  end request 46
#  start request 47
#  end request 47
#  start request 48
#  end request 48
#  start request 49
#  end request 49
# {'model_name': 'sentence-transformer', 'id': 'ab7def89-4062-4f26-af05-7d95d6a8c764', 'parameters': {}, 'outputs': [{'name': 'output-0', 'shape': [5, 384], 'datatype': 'FP32', 'parameters': {'content_type': 'np'}, 'data': [0.2539064884185791, 0.2339666485786438, 0.0008465734426863492, 0.06596261262893677, 0.07323382049798965, 0.1013980507850647, 0.1881396621465683, 0.13714513182640076, -0.07200045883655548, 0.09901047497987747, 0.1096147894859314, -0.007671100553125143, -0.08321959525346756, 0.036644719541072845, -0.14160563051700592, -0.047119688242673874, -0.16945841908454895, -0.09411150217056274, -0.32783395051956177, 0.2539249062538147, -0.17821171879768372, 0.10375