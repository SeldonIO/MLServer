# %% [markdown]
# # Serving a custom model
#
# The `mlserver` package comes with inference runtime implementations for `scikit-learn` and `xgboost` models.
# However, some times we may also need to roll out our own inference server, with custom logic to perform inference.
# To support this scenario, MLServer makes it really easy to create your own extensions, which can then be containerised and deployed in a production environment.

# %% [markdown]
# ## Overview
#
# In this example, we will train a [`numpyro` model](http://num.pyro.ai/en/stable/).
# The `numpyro` library streamlines the implementation of probabilistic models, abstracting away advanced inference and training algorithms.
#
# Out of the box, `mlserver` doesn't provide an inference runtime for `numpyro`.
# However, through this example we will see how easy is to develop our own.

# %% [markdown]
# ## Training
#
# The first step will be to train our model.
# This will be a very simple bayesian regression model, based on an example provided in the [`numpyro` docs](https://nbviewer.jupyter.org/github/pyro-ppl/numpyro/blob/master/notebooks/source/bayesian_regression.ipynb).
#
# Since this is a probabilistic model, during training we will compute an approximation to the posterior distribution of our model using MCMC.

# %%
# Original source code and more details can be found in:
# https://nbviewer.jupyter.org/github/pyro-ppl/numpyro/blob/master/notebooks/source/bayesian_regression.ipynb


import numpyro
import numpy as np
import pandas as pd

from numpyro import distributions as dist
from jax import random
from numpyro.infer import MCMC, NUTS

DATASET_URL = 'https://raw.githubusercontent.com/rmcelreath/rethinking/master/data/WaffleDivorce.csv'
dset = pd.read_csv(DATASET_URL, sep=';')

standardize = lambda x: (x - x.mean()) / x.std()

dset['AgeScaled'] = dset.MedianAgeMarriage.pipe(standardize)
dset['MarriageScaled'] = dset.Marriage.pipe(standardize)
dset['DivorceScaled'] = dset.Divorce.pipe(standardize)

def model(marriage=None, age=None, divorce=None):
    a = numpyro.sample('a', dist.Normal(0., 0.2))
    M, A = 0., 0.
    if marriage is not None:
        bM = numpyro.sample('bM', dist.Normal(0., 0.5))
        M = bM * marriage
    if age is not None:
        bA = numpyro.sample('bA', dist.Normal(0., 0.5))
        A = bA * age
    sigma = numpyro.sample('sigma', dist.Exponential(1.))
    mu = a + M + A
    numpyro.sample('obs', dist.Normal(mu, sigma), obs=divorce)

# Start from this source of randomness. We will split keys for subsequent operations.
rng_key = random.PRNGKey(0)
rng_key, rng_key_ = random.split(rng_key)

num_warmup, num_samples = 1000, 2000

# Run NUTS.
kernel = NUTS(model)
mcmc = MCMC(kernel, num_warmup, num_samples)
mcmc.run(rng_key_, marriage=dset.MarriageScaled.values, divorce=dset.DivorceScaled.values)
mcmc.print_summary()

# %% [markdown]
# ### Saving our trained model
#
# Now that we have _trained_ our model, the next step will be to save it so that it can be loaded afterwards at serving-time.
# Note that, since this is a probabilistic model, we will only need to save the traces that approximate the posterior distribution over latent parameters.
#
# This will get saved in a `numpyro-divorce.json` file.

# %%
import json

samples = mcmc.get_samples()
serialisable = {}
for k, v in samples.items():
    serialisable[k] = np.asarray(v).tolist()
    
model_file_name = "numpyro-divorce.json"
with open(model_file_name, 'w') as model_file:
    json.dump(serialisable, model_file)

# %% [markdown]
# ## Serving
#
# The next step will be to serve our model using `mlserver`.
# For that, we will first implement an extension which serve as the _runtime_ to perform inference using our custom `numpyro` model.

# %% [markdown]
# ### Custom inference runtime
#
# Our custom inference wrapper should be responsible of:
#
# - Loading the model from the set samples we saved previously.
# - Running inference using our model structure, and the posterior approximated from the samples.

# %%
# %%writefile models.py
import json
import numpyro
import numpy as np

from typing import Dict
from jax import random
from mlserver import MLModel, types
from mlserver.utils import get_model_uri
from numpyro.infer import Predictive
from numpyro import distributions as dist


class NumpyroModel(MLModel):
    async def load(self) -> bool:
        model_uri = await get_model_uri(self._settings)
        with open(model_uri) as model_file:
            raw_samples = json.load(model_file)

        self._samples = {}
        for k, v in raw_samples.items():
            self._samples[k] = np.array(v)

        self._predictive = Predictive(self._model, self._samples)

        self.ready = True
        return self.ready

    async def predict(self, payload: types.InferenceRequest) -> types.InferenceResponse:
        inputs = self._extract_inputs(payload)
        predictions = self._predictive(rng_key=random.PRNGKey(0), **inputs)

        obs = predictions["obs"]
        obs_mean = obs.mean()

        return types.InferenceResponse(
            id=payload.id,
            model_name=self.name,
            model_version=self.version,
            outputs=[
                types.ResponseOutput(
                    name="obs_mean",
                    shape=obs_mean.shape,
                    datatype="FP32",
                    data=np.asarray(obs_mean).tolist(),
                )
            ],
        )

    def _extract_inputs(self, payload: types.InferenceRequest) -> Dict[str, np.ndarray]:
        inputs = {}
        for inp in payload.inputs:
            inputs[inp.name] = np.array(inp.data)

        return inputs

    def _model(self, marriage=None, age=None, divorce=None):
        a = numpyro.sample("a", dist.Normal(0.0, 0.2))
        M, A = 0.0, 0.0
        if marriage is not None:
            bM = numpyro.sample("bM", dist.Normal(0.0, 0.5))
            M = bM * marriage
        if age is not None:
            bA = numpyro.sample("bA", dist.Normal(0.0, 0.5))
            A = bA * age
        sigma = numpyro.sample("sigma", dist.Exponential(1.0))
        mu = a + M + A
        numpyro.sample("obs", dist.Normal(mu, sigma), obs=divorce)

# %% [markdown]
# ### Settings files
#
# The next step will be to create 2 configuration files:
#
# - `settings.json`: holds the configuration of our server (e.g. ports, log level, etc.).
# - `model-settings.json`: holds the configuration of our model (e.g. input type, runtime to use, etc.).

# %% [markdown]
# #### `settings.json`

# %%
# %%writefile settings.json
# {
#     "debug": "true"
# }
# Out:
# Overwriting settings.json

# %% [markdown]
# #### `model-settings.json`

# %%
# %%writefile model-settings.json
# {
#     "name": "numpyro-divorce",
#     "implementation": "models.NumpyroModel",
#     "parameters": {
#         "uri": "./numpyro-divorce.json"
#     }
# }
# Out:
# Overwriting model-settings.json

# %% [markdown]
# ### Start serving our model
#
# Now that we have our config in-place, we can start the server by running `mlserver start .`. This needs to either be ran from the same directory where our config files are or pointing to the folder where they are.
#
# ```shell
# mlserver start .
# ```
#
# Since this command will start the server and block the terminal, waiting for requests, this will need to be ran in the background on a separate terminal.

# %% [markdown]
# ### Send test inference request
#
#
# We now have our model being served by `mlserver`.
# To make sure that everything is working as expected, let's send a request from our test set.
#
# For that, we can use the Python types that `mlserver` provides out of box, or we can build our request manually.

# %%
import requests

x_0 = [28.0]
inference_request = {
    "inputs": [
        {
          "name": "marriage",
          "shape": [1],
          "datatype": "FP32",
          "data": x_0
        }
    ]
}

endpoint = "http://localhost:8080/v2/models/numpyro-divorce/infer"
response = requests.post(endpoint, json=inference_request)

response.json()

# %% [markdown]
# ## Deployment
#
# Now that we have written and tested our custom model, the next step is to deploy it.
# With that goal in mind, the rough outline of steps will be to first build a custom image containing our code, and then deploy it.

# %% [markdown]
# ### Building a custom image

# %% [markdown]
# MLServer offers helpers to build a custom Docker image containing your code.
# In this example, we will use the `mlserver build` subcommand to create an image, which we'll be able to deploy later.
#
#
# Note that this section expects that Docker is available and running in the background, as well as a functional cluster with Seldon Core installed and some familiarity with `kubectl`.

# %%
# %%bash
# mlserver build . -t 'my-custom-numpyro-server'
# Out:
# 2021-10-28 11:09:05,846 [mlserver] INFO - Building Docker image with tag my-custom-numpyro-server
# 2021-10-28 11:09:05,846 [mlserver] INFO - Writing Dockerfile in /tmp/tmpghb47v_b/Dockerfile
# 2021-10-28 11:09:05,846 [mlserver] INFO - Writing .dockerignore in /tmp/tmpghb47v_b/Dockerfile.dockerignore
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (1/2)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
# [+] Building 0.3s (3/4)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.1s
# [+] Building 0.4s (3/4)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.2s
# [+] Building 0.6s (3/4)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.4s
# [+] Building 0.7s (3/4)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.5s
# [+] Building 0.8s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
# [+] Building 1.0s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    0.1s
# [+] Building 1.1s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    0.3s
# [+] Building 1.3s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    0.5s
# [+] Building 1.4s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    0.6s
# [+] Building 1.6s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    0.8s
# [+] Building 1.7s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    0.9s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
# [+] Building 1.9s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.1s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
# [+] Building 2.0s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.2s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
# [+] Building 2.2s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.4s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
# [+] Building 2.3s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.5s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
# [+] Building 2.5s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.7s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
# [+] Building 2.6s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.8s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
# [+] Building 2.8s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    1.9s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
# [+] Building 2.9s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    2.1s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
# [+] Building 3.1s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    2.2s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
# [+] Building 3.2s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    2.4s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
# [+] Building 3.4s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    2.5s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
# [+] Building 3.5s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    2.7s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 3.7s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    2.8s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 3.8s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.0s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.0s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.1s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.1s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.3s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.3s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.4s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.4s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.6s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.6s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.7s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.7s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    3.9s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 4.9s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                    4.0s
#  => => # ---> Found custom requirements.txt at ./requirements.txt
#  => => # Defaulting to user installation because normal site-packages is not wr
#  => => # iteable
#  => => # Collecting numpy==1.18.5
#  => => #   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# [+] Building 5.0s (12/14)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
# ...
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    2.4s
# [+] Building 29.4s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     2.5s
#  => => exporting layers                                                    2.5s
# [+] Building 29.6s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     2.7s
#  => => exporting layers                                                    2.7s
# [+] Building 29.7s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     2.8s
#  => => exporting layers                                                    2.8s
# [+] Building 29.9s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     3.0s
#  => => exporting layers                                                    3.0s
# [+] Building 30.0s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     3.1s
#  => => exporting layers                                                    3.1s
# [+] Building 30.2s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     3.3s
#  => => exporting layers                                                    3.3s
# [+] Building 30.3s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     3.4s
#  => => exporting layers                                                    3.4s
# [+] Building 30.5s (14/15)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     3.6s
#  => => exporting layers                                                    3.6s
# [+] Building 30.5s (15/15) FINISHED
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 2.07kB                                     0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/seldonio/mlserver:0.6.0.dev1-s  0.0s
#  => [internal] load metadata for docker.io/continuumio/miniconda3:4.10.3   0.6s
#  => [env-builder 1/4] FROM docker.io/continuumio/miniconda3:4.10.3@sha256  0.0s
#  => [stage-1 1/5] FROM docker.io/seldonio/mlserver:0.6.0.dev1-slim         0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 214.46kB                                      0.0s
#  => CACHED [env-builder 2/4] RUN conda config --add channels conda-forge   0.0s
#  => CACHED [env-builder 3/4] COPY     ./environment.ym[l]     ./environme  0.0s
#  => CACHED [env-builder 4/4] RUN mkdir $(dirname ./envs/base.tar.gz);      0.0s
#  => CACHED [stage-1 2/5] COPY     --chown=1000     --from=env-builder      0.0s
#  => [stage-1 3/5] COPY     ./settings.jso[n]     ./model-settings.jso[n]   0.0s
#  => [stage-1 4/5] RUN ./hack/build-env.sh . ./envs/base                   25.9s
#  => [stage-1 5/5] COPY . .                                                 0.2s
#  => exporting to image                                                     3.6s
#  => => exporting layers                                                    3.6s
#  => => writing image sha256:0576584e5ce63260e2cf4f3d43c11548bc24d3196d625  0.0s
#  => => naming to docker.io/library/my-custom-numpyro-server                0.0s
# 2021-10-28 11:09:36,529 [mlserver] INFO - Successfully built custom Docker image with tag my-custom-numpyro-server

# %% [markdown]
# To ensure that the image is fully functional, we can spin up a container and then send a test request. To start the container, you can run something along the following lines in a separate terminal:
#
# ```bash
# docker run -it --rm -p 8080:8080 my-custom-numpyro-server
# ```

# %%
import requests

x_0 = [28.0]
inference_request = {
    "inputs": [
        {
          "name": "marriage",
          "shape": [1],
          "datatype": "FP32",
          "data": x_0
        }
    ]
}

endpoint = "http://localhost:8080/v2/models/numpyro-divorce/infer"
response = requests.post(endpoint, json=inference_request)

response.json()
# Out:
# {'model_name': 'numpyro-divorce',
#  'model_version': None,
#  'id': '7abb5b05-5d86-40e1-ad80-e3793c01739e',
#  'parameters': None,
#  'outputs': [{'name': 'obs_mean',
#    'shape': [],
#    'datatype': 'FP32',
#    'parameters': None,
#    'data': 9.698766708374023}]}

# %% [markdown]
# As we should be able to see, the server running within our Docker image responds as expected.

# %% [markdown]
# ### Deploying our custom image
#
# Note that this section expects access to a functional cluster with Seldon Core installed and some familiarity with `kubectl`.
#
# Now that we've built a custom image and verified that it works as expected, we can move to the next step and deploy it.
# There is a large number of tools out there to deploy images.
# However, for our example, we will focus on deploying it to a cluster running [Seldon Core](https://docs.seldon.io/projects/seldon-core/en/latest/).
#
# For that, we will need to create a `SeldonDeployment` resource which instructs Seldon Core to deploy a model embedded within our custom image and compliant with the [V2 Inference Protocol](https://github.com/kserve/kserve/tree/master/docs/predict-api/v2).
# This can be achieved by _applying_ a `SeldonDeployment` manifest to the cluster, similar to the one below:

# %%
# %%writefile seldondeployment.yaml
# apiVersion: machinelearning.seldon.io/v1
# kind: SeldonDeployment
# metadata:
#   name: numpyro-model
# spec:
#   predictors:
#     - name: default
#       annotations:
#         seldon.io/no-engine: "true"
#       graph:
#         name: mlflow-model
#         type: MODEL
#       componentSpecs:
#         - spec:
#             containers:
#               - name: mlflow-model
#                 image: my-custom-numpyro-server
#                 ports:
#                   - containerPort: 8080
#                     name: http
#                     protocol: TCP
#                   - containerPort: 8081
#                     name: grpc
#                     protocol: TCP
# Out:
# Writing seldondeployment.yaml
